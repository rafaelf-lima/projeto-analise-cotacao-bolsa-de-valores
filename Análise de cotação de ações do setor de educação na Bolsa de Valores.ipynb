# %%
import pandas as pd
from pandas_datareader import data as web
import matplotlib.pyplot as plt

# %%
cotacao = web.DataReader('YDUQ3.SA', data_source = 'yahoo', start = '07-20-2021', end = '07-20-2022')
display(cotacao)
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2021-07-20  32.320000  31.650000  31.910000  32.139999   852600.0  31.898779
# 2021-07-21  32.160000  31.219999  32.119999  31.620001  1584800.0  31.382683
# 2021-07-22  31.780001  31.139999  31.650000  31.330000  1343600.0  31.094858
# 2021-07-23  31.370001  30.480000  31.160000  30.799999  1517500.0  30.568836
# 2021-07-26  31.170000  30.200001  30.809999  30.440001  1466000.0  30.211540
# ...               ...        ...        ...        ...        ...        ...
# 2022-07-14  14.270000  13.550000  13.730000  14.150000  5931200.0  14.150000
# 2022-07-15  14.800000  13.820000  14.150000  14.720000  4705500.0  14.720000
# 2022-07-18  15.560000  14.480000  14.730000  14.710000  5251900.0  14.710000
# 2022-07-19  14.880000  13.340000  14.740000  14.120000  7155700.0  14.120000
# 2022-07-20  14.610000  13.350000  13.960000  14.290000  5088100.0  14.290000
#
# [251 rows x 6 columns]

# %%
cotacao['Adj Close'].plot(figsize = (15,10))
plt.title("Fechamento ajustado durante 20/07/2021 e 20/07/2022 - YDUQ3.SA", 
        fontsize='large',
        fontweight='bold',
        style='italic',
        family='monospace')
plt.show()

# %%
cotacaoc = web.DataReader('COGN3.SA', data_source = 'yahoo', start = '07-20-2021', end = '07-20-2022')
display(cotacaoc)
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# Date
# 2021-07-20  4.12  4.04  4.07   4.07  22119600       4.07
# 2021-07-21  4.08  3.95  4.08   3.97  44833900       3.97
# 2021-07-22  4.02  3.92  3.96   3.95  28389500       3.95
# 2021-07-23  3.97  3.87  3.94   3.87  25516100       3.87
# 2021-07-26  3.92  3.78  3.87   3.79  31638700       3.79
# ...          ...   ...   ...    ...       ...        ...
# 2022-07-14  2.41  2.29  2.30   2.39  29517200       2.39
# 2022-07-15  2.45  2.33  2.39   2.42  35004600       2.42
# 2022-07-18  2.51  2.38  2.44   2.41  26943600       2.41
# 2022-07-19  2.43  2.30  2.42   2.33  27936200       2.33
# 2022-07-20  2.34  2.17  2.28   2.32  57092300       2.32
#
# [251 rows x 6 columns]

# %%
cotacaoc['Adj Close'].plot(figsize = (15,10))
plt.title("Fechamento ajustado durante 20/07/2021 e 20/07/2022 - COGN3.SA", 
        fontsize='large',
        fontweight='bold',
        style='italic',
        family='monospace')
plt.show()

# %%
cotacaoa = web.DataReader('ANIM3.SA', data_source = 'yahoo', start = '07-20-2021', end = '07-20-2022')
display(cotacaoa)
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2021-07-20  12.57  12.31  12.34  12.47    894600      12.47
# 2021-07-21  12.49  11.88  12.38  12.00   4481700      12.00
# 2021-07-22  12.44  11.90  11.90  12.36   2067600      12.36
# 2021-07-23  12.37  12.10  12.36  12.31   2029500      12.31
# 2021-07-26  12.32  11.87  12.32  11.96   1664700      11.96
# ...           ...    ...    ...    ...       ...        ...
# 2022-07-14   4.49   4.25   4.27   4.45   4182300       4.45
# 2022-07-15   4.59   4.37   4.42   4.54  15082500       4.54
# 2022-07-18   4.78   4.53   4.58   4.57   2093200       4.57
# 2022-07-19   4.63   4.33   4.58   4.39   2836900       4.39
# 2022-07-20   4.66   4.29   4.35   4.63   2277300       4.63
#
# [251 rows x 6 columns]

# %%
cotacaoa['Adj Close'].plot(figsize = (15,10))
plt.title("Fechamento ajustado durante 20/07/2021 e 20/07/2022 - ANIM3.SA", 
        fontsize='large',
        fontweight='bold',
        style='italic',
        family='monospace')
plt.show()
